# %%
import time
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('../data/weather_features.csv')
df.tail()
# Out:
#                            dt_iso city_name    temp  temp_min  temp_max  \
# 178391  2018-12-31 19:00:00+01:00   Seville  287.76    287.15    288.15
# 178392  2018-12-31 20:00:00+01:00   Seville  285.76    285.15    286.15
# 178393  2018-12-31 21:00:00+01:00   Seville  285.15    285.15    285.15
# 178394  2018-12-31 22:00:00+01:00   Seville  284.15    284.15    284.15
# 178395  2018-12-31 23:00:00+01:00   Seville  283.97    282.15    285.15
#
#         pressure  humidity  wind_speed  wind_deg  rain_1h  rain_3h  snow_3h  \
# 178391      1028        54           3        30      0.0      0.0      0.0
# 178392      1029        62           3        30      0.0      0.0      0.0
# 178393      1028        58           4        50      0.0      0.0      0.0
# 178394      1029        57           4        60      0.0      0.0      0.0
# 178395      1029        70           3        50      0.0      0.0      0.0
#
#         clouds_all  weather_id weather_main weather_description weather_icon
# 178391           0         800        clear        sky is clear          01n
# 178392           0         800        clear        sky is clear          01n
# 178393           0         800        clear        sky is clear          01n
# 178394           0         800        clear        sky is clear          01n
# 178395           0         800        clear        sky is clear          01n

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178396 entries, 0 to 178395
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dt_iso               178396 non-null  object
#  1   city_name            178396 non-null  object
#  2   temp                 178396 non-null  float64
#  3   temp_min             178396 non-null  float64
#  4   temp_max             178396 non-null  float64
#  5   pressure             178396 non-null  int64
#  6   humidity             178396 non-null  int64
#  7   wind_speed           178396 non-null  int64
#  8   wind_deg             178396 non-null  int64
#  9   rain_1h              178396 non-null  float64
#  10  rain_3h              178396 non-null  float64
#  11  snow_3h              178396 non-null  float64
#  12  clouds_all           178396 non-null  int64
#  13  weather_id           178396 non-null  int64
#  14  weather_main         178396 non-null  object
#  15  weather_description  178396 non-null  object
#  16  weather_icon         178396 non-null  object
# dtypes: float64(6), int64(6), object(5)
# memory usage: 23.1+ MB

# %%
df['city_name'].value_counts()
# Out:
# Madrid        36267
# Bilbao        35951
# Seville       35557
#  Barcelona    35476
# Valencia      35145
# Name: city_name, dtype: int64

# %%
df_Madrid = df.query('city_name == "Madrid"').copy()
df_Madrid.tail()
# Out:
#                           dt_iso city_name    temp  temp_min  temp_max  \
# 71407  2018-12-31 19:00:00+01:00    Madrid  283.56    282.15    285.15
# 71408  2018-12-31 20:00:00+01:00    Madrid  280.12    278.15    281.15
# 71409  2018-12-31 21:00:00+01:00    Madrid  278.15    278.15    278.15
# 71410  2018-12-31 22:00:00+01:00    Madrid  276.57    276.15    277.15
# 71411  2018-12-31 23:00:00+01:00    Madrid  275.15    275.15    275.15
#
#        pressure  humidity  wind_speed  wind_deg  rain_1h  rain_3h  snow_3h  \
# 71407      1030        88           1       280      0.0      0.0      0.0
# 71408      1031        52           1       260      0.0      0.0      0.0
# 71409      1030        65           1       340      0.0      0.0      0.0
# 71410      1031        69           2       340      0.0      0.0      0.0
# 71411      1031        74           1       360      0.0      0.0      0.0
#
#        clouds_all  weather_id weather_main weather_description weather_icon
# 71407           0         800        clear        sky is clear          01n
# 71408           0         800        clear        sky is clear          01n
# 71409           0         800        clear        sky is clear          01n
# 71410           0         800        clear        sky is clear          01n
# 71411           0         800        clear        sky is clear          01n

# %%
df_Madrid['dt_iso'] = pd.to_datetime(df_Madrid['dt_iso'], utc=True)
df_Madrid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36267 entries, 35145 to 71411
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dt_iso               36267 non-null  datetime64[ns, UTC]
#  1   city_name            36267 non-null  object
#  2   temp                 36267 non-null  float64
#  3   temp_min             36267 non-null  float64
#  4   temp_max             36267 non-null  float64
#  5   pressure             36267 non-null  int64
#  6   humidity             36267 non-null  int64
#  7   wind_speed           36267 non-null  int64
#  8   wind_deg             36267 non-null  int64
#  9   rain_1h              36267 non-null  float64
#  10  rain_3h              36267 non-null  float64
#  11  snow_3h              36267 non-null  float64
#  12  clouds_all           36267 non-null  int64
#  13  weather_id           36267 non-null  int64
#  14  weather_main         36267 non-null  object
#  15  weather_description  36267 non-null  object
#  16  weather_icon         36267 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(6), int64(6), object(4)
# memory usage: 5.0+ MB

# %%
df_Madrid['weather_main'].value_counts()
# Out:
# clear           20356
# clouds          10643
# rain             2657
# mist              938
# fog               708
# drizzle           637
# thunderstorm      222
# snow               88
# haze               18
# Name: weather_main, dtype: int64

# %%
le_main = LabelEncoder()
df_Madrid['weather_main'] = le_main.fit_transform(df_Madrid['weather_main'])

# %%
df_Madrid['weather_main'].value_counts()
# Out:
# 0    20356
# 1    10643
# 6     2657
# 5      938
# 3      708
# 2      637
# 8      222
# 7       88
# 4       18
# Name: weather_main, dtype: int64

# %%
le_desc = LabelEncoder()
df_Madrid['weather_description'] = le_desc.fit_transform(df_Madrid['weather_description'])
le_icon = LabelEncoder()
df_Madrid['weather_icon'] = le_icon.fit_transform(df_Madrid['weather_icon'])
df_Madrid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36267 entries, 35145 to 71411
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dt_iso               36267 non-null  datetime64[ns, UTC]
#  1   city_name            36267 non-null  object
#  2   temp                 36267 non-null  float64
#  3   temp_min             36267 non-null  float64
#  4   temp_max             36267 non-null  float64
#  5   pressure             36267 non-null  int64
#  6   humidity             36267 non-null  int64
#  7   wind_speed           36267 non-null  int64
#  8   wind_deg             36267 non-null  int64
#  9   rain_1h              36267 non-null  float64
#  10  rain_3h              36267 non-null  float64
#  11  snow_3h              36267 non-null  float64
#  12  clouds_all           36267 non-null  int64
#  13  weather_id           36267 non-null  int64
#  14  weather_main         36267 non-null  int64
#  15  weather_description  36267 non-null  int64
#  16  weather_icon         36267 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(6), int64(9), object(1)
# memory usage: 5.0+ MB

# %%
df_Madrid.set_index('dt_iso', inplace=True)
df_Madrid
# Out:
#                           city_name     temp  temp_min  temp_max  pressure  \
# dt_iso
# 2014-12-31 23:00:00+00:00    Madrid  267.325   267.325   267.325       971
# 2015-01-01 00:00:00+00:00    Madrid  267.325   267.325   267.325       971
# 2015-01-01 01:00:00+00:00    Madrid  266.186   266.186   266.186       971
# 2015-01-01 02:00:00+00:00    Madrid  266.186   266.186   266.186       971
# 2015-01-01 03:00:00+00:00    Madrid  266.186   266.186   266.186       971
# ...                             ...      ...       ...       ...       ...
# 2018-12-31 18:00:00+00:00    Madrid  283.560   282.150   285.150      1030
# 2018-12-31 19:00:00+00:00    Madrid  280.120   278.150   281.150      1031
# 2018-12-31 20:00:00+00:00    Madrid  278.150   278.150   278.150      1030
# 2018-12-31 21:00:00+00:00    Madrid  276.570   276.150   277.150      1031
# 2018-12-31 22:00:00+00:00    Madrid  275.150   275.150   275.150      1031
#
#                            humidity  wind_speed  wind_deg  rain_1h  rain_3h  \
# dt_iso
# 2014-12-31 23:00:00+00:00        63           1       309      0.0      0.0
# 2015-01-01 00:00:00+00:00        63           1       309      0.0      0.0
# 2015-01-01 01:00:00+00:00        64           1       273      0.0      0.0
# 2015-01-01 02:00:00+00:00        64           1       273      0.0      0.0
# 2015-01-01 03:00:00+00:00        64           1       273      0.0      0.0
# ...                             ...         ...       ...      ...      ...
# 2018-12-31 18:00:00+00:00        88           1       280      0.0      0.0
# 2018-12-31 19:00:00+00:00        52           1       260      0.0      0.0
# 2018-12-31 20:00:00+00:00        65           1       340      0.0      0.0
# 2018-12-31 21:00:00+00:00        69           2       340      0.0      0.0
# 2018-12-31 22:00:00+00:00        74           1       360      0.0      0.0
#
#                            snow_3h  clouds_all  weather_id  weather_main  \
# dt_iso
# 2014-12-31 23:00:00+00:00      0.0           0         800             0
# 2015-01-01 00:00:00+00:00      0.0           0         800             0
# 2015-01-01 01:00:00+00:00      0.0           0         800             0
# 2015-01-01 02:00:00+00:00      0.0           0         800             0
# 2015-01-01 03:00:00+00:00      0.0           0         800             0
# ...                            ...         ...         ...           ...
# 2018-12-31 18:00:00+00:00      0.0           0         800             0
# 2018-12-31 19:00:00+00:00      0.0           0         800             0
# 2018-12-31 20:00:00+00:00      0.0           0         800             0
# 2018-12-31 21:00:00+00:00      0.0           0         800             0
# 2018-12-31 22:00:00+00:00      0.0           0         800             0
#
#                            weather_description  weather_icon
# dt_iso
# 2014-12-31 23:00:00+00:00                   25             2
# 2015-01-01 00:00:00+00:00                   25             2
# 2015-01-01 01:00:00+00:00                   25             2
# 2015-01-01 02:00:00+00:00                   25             2
# 2015-01-01 03:00:00+00:00                   25             2
# ...                                        ...           ...
# 2018-12-31 18:00:00+00:00                   25             2
# 2018-12-31 19:00:00+00:00                   25             2
# 2018-12-31 20:00:00+00:00                   25             2
# 2018-12-31 21:00:00+00:00                   25             2
# 2018-12-31 22:00:00+00:00                   25             2
#
# [36267 rows x 16 columns]

# %%
df_Madrid['temp'] = df_Madrid['temp'].shift(periods=-3, freq="h")
df_Madrid
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qp/lp_5yt3s65q_pj__6v_kdvnh0000gn/T/ipykernel_8964/2475516962.py in <module>
# ----> 1 df_Madrid['temp'] = df_Madrid['temp'].shift(periods=-3, freq="h")
#       2 df_Madrid
#
# ~/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4504         # We should never get here with DataFrame value
#    4505         if isinstance(value, Series):
# -> 4506             return _reindex_for_setitem(value, self.index)
#    4507
#    4508         if is_list_like(value):
#
# ~/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_for_setitem(value, index)
#   10778         if not value.index.is_unique:
#   10779             # duplicate axis
# > 10780             raise err
#   10781
#   10782         raise TypeError(
#
# ~/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_for_setitem(value, index)
#   10773     # GH#4107
#   10774     try:
# > 10775         reindexed_value = value.reindex(index)._values
#   10776     except ValueError as err:
#   10777         # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#
# ~/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    4578     )
#    4579     def reindex(self, index=None, **kwargs):
# -> 4580         return super().reindex(index=index, **kwargs)
#    4581
#    4582     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ~/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4817         # perform the reindex on the axes
#    4818         return self._reindex_axes(
# -> 4819             axes, level, limit, tolerance, method, fill_value, copy
#    4820         ).__finalize__(self, method="reindex")
#    4821
#
# ~/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4841                 fill_value=fill_value,
#    4842                 copy=copy,
# -> 4843                 allow_dups=False,
#    4844             )
#    4845
#
# ~/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4887                 fill_value=fill_value,
#    4888                 allow_dups=allow_dups,
# -> 4889                 copy=copy,
#    4890             )
#    4891             # If we've made a copy once, no need to make another one
#
# ~/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     668         # some axes don't allow reindexing with dups
#     669         if not allow_dups:
# --> 670             self.axes[axis]._validate_can_reindex(indexer)
#     671
#     672         if axis >= self.ndim:
#
# ~/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/pandas/core/indexes/base.py in _validate_can_reindex(self, indexer)
#    3783         # trying to reindex on an axis with duplicates
#    3784         if not self._index_as_unique and len(indexer):
# -> 3785             raise ValueError("cannot reindex from a duplicate axis")
#    3786
#    3787     def reindex(
#
# ValueError: cannot reindex from a duplicate axis

# %%
df_Madrid = df_Madrid[~df_Madrid.index.duplicated()]

# %%
df_Madrid['temp'] = df_Madrid['temp'].shift(periods=-3, freq="h")
df_Madrid
# Out:
# /Users/mesmalif/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                           city_name     temp  temp_min  temp_max  pressure  \
# dt_iso
# 2014-12-31 23:00:00+00:00    Madrid  266.186   267.325   267.325       971
# 2015-01-01 00:00:00+00:00    Madrid  266.186   267.325   267.325       971
# 2015-01-01 01:00:00+00:00    Madrid  265.442   266.186   266.186       971
# 2015-01-01 02:00:00+00:00    Madrid  265.442   266.186   266.186       971
# 2015-01-01 03:00:00+00:00    Madrid  265.442   266.186   266.186       971
# ...                             ...      ...       ...       ...       ...
# 2018-12-31 18:00:00+00:00    Madrid  276.570   282.150   285.150      1030
# 2018-12-31 19:00:00+00:00    Madrid  275.150   278.150   281.150      1031
# 2018-12-31 20:00:00+00:00    Madrid      NaN   278.150   278.150      1030
# 2018-12-31 21:00:00+00:00    Madrid      NaN   276.150   277.150      1031
# 2018-12-31 22:00:00+00:00    Madrid      NaN   275.150   275.150      1031
#
#                            humidity  wind_speed  wind_deg  rain_1h  rain_3h  \
# dt_iso
# 2014-12-31 23:00:00+00:00        63           1       309      0.0      0.0
# 2015-01-01 00:00:00+00:00        63           1       309      0.0      0.0
# 2015-01-01 01:00:00+00:00        64           1       273      0.0      0.0
# 2015-01-01 02:00:00+00:00        64           1       273      0.0      0.0
# 2015-01-01 03:00:00+00:00        64           1       273      0.0      0.0
# ...                             ...         ...       ...      ...      ...
# 2018-12-31 18:00:00+00:00        88           1       280      0.0      0.0
# 2018-12-31 19:00:00+00:00        52           1       260      0.0      0.0
# 2018-12-31 20:00:00+00:00        65           1       340      0.0      0.0
# 2018-12-31 21:00:00+00:00        69           2       340      0.0      0.0
# 2018-12-31 22:00:00+00:00        74           1       360      0.0      0.0
#
#                            snow_3h  clouds_all  weather_id  weather_main  \
# dt_iso
# 2014-12-31 23:00:00+00:00      0.0           0         800             0
# 2015-01-01 00:00:00+00:00      0.0           0         800             0
# 2015-01-01 01:00:00+00:00      0.0           0         800             0
# 2015-01-01 02:00:00+00:00      0.0           0         800             0
# 2015-01-01 03:00:00+00:00      0.0           0         800             0
# ...                            ...         ...         ...           ...
# 2018-12-31 18:00:00+00:00      0.0           0         800             0
# 2018-12-31 19:00:00+00:00      0.0           0         800             0
# 2018-12-31 20:00:00+00:00      0.0           0         800             0
# 2018-12-31 21:00:00+00:00      0.0           0         800             0
# 2018-12-31 22:00:00+00:00      0.0           0         800             0
#
#                            weather_description  weather_icon
# dt_iso
# 2014-12-31 23:00:00+00:00                   25             2
# 2015-01-01 00:00:00+00:00                   25             2
# 2015-01-01 01:00:00+00:00                   25             2
# 2015-01-01 02:00:00+00:00                   25             2
# 2015-01-01 03:00:00+00:00                   25             2
# ...                                        ...           ...
# 2018-12-31 18:00:00+00:00                   25             2
# 2018-12-31 19:00:00+00:00                   25             2
# 2018-12-31 20:00:00+00:00                   25             2
# 2018-12-31 21:00:00+00:00                   25             2
# 2018-12-31 22:00:00+00:00                   25             2
#
# [35064 rows x 16 columns]

# %%
df_Madrid['temp'] = df_Madrid['temp'].fillna(method='ffill')
df_Madrid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35064 entries, 2014-12-31 23:00:00+00:00 to 2018-12-31 22:00:00+00:00
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   city_name            35064 non-null  object
#  1   temp                 35064 non-null  float64
#  2   temp_min             35064 non-null  float64
#  3   temp_max             35064 non-null  float64
#  4   pressure             35064 non-null  int64
#  5   humidity             35064 non-null  int64
#  6   wind_speed           35064 non-null  int64
#  7   wind_deg             35064 non-null  int64
#  8   rain_1h              35064 non-null  float64
#  9   rain_3h              35064 non-null  float64
#  10  snow_3h              35064 non-null  float64
#  11  clouds_all           35064 non-null  int64
#  12  weather_id           35064 non-null  int64
#  13  weather_main         35064 non-null  int64
#  14  weather_description  35064 non-null  int64
#  15  weather_icon         35064 non-null  int64
# dtypes: float64(6), int64(9), object(1)
# memory usage: 4.5+ MB
# /Users/mesmalif/opt/anaconda3/envs/env_canvas/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
target = 'temp'
features = df_Madrid.columns.drop([target, 'city_name'])

# %%
X = df_Madrid[features].values
y = df_Madrid[target].values

# %%
lr = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([305.94200755, 277.00144563, 279.46796103, ..., 284.16655864,
#        286.96936047, 294.65814226])

# %%
y_test
# Out:
# array([302.1  , 277.64 , 281.73 , ..., 279.15 , 283.484, 288.57 ])

# %%
mean_squared_error(y_pred, y_test)**.5
# Out:
# 3.1830558684850954
